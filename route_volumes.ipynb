# %%
from methods import load_data, select_volume_data, group_nodes, group_links, obtain_routes, export_results, select_route_data
import pathlib

# %%
file = pathlib.Path.cwd() / "Enfield Saturn Routes AM test.xlsx"

# %%
strategic_raw_data, qgis_table = load_data(file, file)

# %% [markdown]
# Get the volumes "Flow" associated with each of the routes

# %%
nodes= select_route_data(strategic_raw_data)

# %%
volumes=select_volume_data(strategic_raw_data)

# %%
volumes
# Out:
# ['0.020769',
#  '0.762151',
#  '1.220964',
#  '0.471203',
#  '0.481190',
#  '0.038812',
#  '0.018984',
#  '0.117868',
#  '0.088401',
#  '0.543961',
#  '0.211153',
#  '0.404332',
#  '1.601578',
#  '0.038497',
#  '0.039052',
#  '0.115233',
#  '0.055908',
#  '0.041931',
#  '0.531646',
#  '0.317559',
#  '1.925218',
#  '0.990554',
#  '0.194620',
#  '0.130463',
#  '0.205001',
#  '0.013141',
#  '0.012547',
#  '0.040787',
#  '0.025692',
#  '0.043281',
#  '0.175850',
#  '0.026764',
#  '0.011617',
#  '0.041989',
#  '0.180131',
#  '0.217480',
#  '0.349191',
#  '0.098772',
#  '3.447800',
#  '0.347885',
#  '0.207912',
#  '2.587975',
#  '0.225191',
#  '1.136517',
#  '1.458344',
#  '0.539629',
#  '0.741536',
#  '0.539251',
#  '11.238258',
#  '16.264105',
#  '13.642067',
#  '1.043872',
#  '0.171676',
#  '0.123253',
#  '8.072878',
#  '0.693854',
#  '0.247075',
#  '0.178042',
#  '0.492384',
#  '0.248546',
#  '12.130300',
#  '0.554619',
#  '4.886425',
#  '1.753168',
#  '0.519571',
#  '0.054325',
# ...

# %%
len(volumes)
# Out:
# 824

# %% [markdown]
# Get all flows only, assign to dict witht the routes, group?
